# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open("chemical_shifts.pkl", "rb") as infile:
        chemical_shifts = pickle.load(infile)

# %%
chemical_shifts[3322]
# Out:
#     sequence chem_comp_ID  X_shift  Y_shift X_atom_name Y_atom_name
# 0          2          SER     8.31   123.30           H           N
# 1          3          CYS     8.20   116.30           H           N
# 2          4          TRP     9.44   130.00           H           N
# 3          5          ALA     5.80   122.60           H           N
# 4          6          GLN     7.29   121.15           H           N
# 5          7          SER     8.23   110.30           H           N
# 6          8          GLN     7.78   118.20           H           N
# 7          9          GLY     7.84   105.70           H           N
# 8         10          TYR     7.55   118.60           H           N
# 9         11          ASN     8.83   115.80           H           N
# 10        12          CYS     8.39   116.80           H           N
# 11        13          CYS     8.48   121.20           H           N
# 12        14          ASN     9.48   123.40           H           N
# 13        15          ASN     9.09   115.20           H           N
# 14        17          SER     8.52   111.40           H           N
# 15        18          SER     7.74   114.40           H           N
# 16        19          THR     7.34   120.40           H           N
# 17        20          LYS     8.74   129.30           H           N
# 18        21          VAL     8.70   127.00           H           N
# 19        22          GLU     9.70   130.10           H           N
# 20        23          TYR     8.11   117.60           H           N
# 21        24          THR     7.83   119.60           H           N
# 22        25          ASP     9.21   127.60           H           N
# 23        26          ALA     8.23   118.30           H           N
# 24        27          SER     8.34   113.10           H           N
# 25        28          GLY     7.48   107.10           H           N
# 26        29          GLN     8.24   117.10           H           N
# 27        30          TRP     9.12   121.20           H           N
# 28        31          GLY     9.52   111.00           H           N
# 29        32          VAL     8.88   118.30           H           N
# 30        33          GLN     8.81   124.30           H           N
# 31        34          ASN     8.16   119.60           H           N
# 32        35          GLY     8.57   102.90           H           N
# 33        36          GLN     7.68   119.30           H           N
# 34        37          TRP     8.51   123.90           H           N
# 35        38          CYS     9.67   117.10           H           N
# 36        39          GLY     8.58   109.20           H           N
# 37        40          ILE     8.93   128.40           H           N
# 38        41          ASP     8.86   132.00           H           N
# 39        42          TYR     9.14   125.20           H           N
# 40        43          SER     9.26   116.40           H           N
# 41        44          TYR     7.96   125.40           H           N
# 42        45          GLY     8.04   112.90           H           N
# 43        46          GLN     8.00   119.30           H           N
# 44        47          ASN     8.64   120.20           H           N
# 45        48          GLN     8.55   121.60           H           N
# 46        49          GLY     8.55   110.10           H           N
# 47        50          ASN     8.39   118.70           H           N
# 48        51          GLU     8.53   120.80           H           N
# 49        52          SER     8.03   122.30           H           N

# %% [markdown]
# # H-Shifts

# %%
plt.figure(figsize=(15,10))
for sheet in chemical_shifts.values():
    plt.hist(sheet.X_shift, 150, density=False, alpha=0.75, histtype="stepfilled", color="black")
plt.title("H-Shifts")
plt.show()

# %% [markdown]
# ## Filtering

# %%
H_to_large_or_small = []
for bmrb_id, sheet in chemical_shifts.items():
    if max(sheet.X_shift) > 15 or min(sheet.X_shift) < 0:
        print(bmrb_id, ":", "max --> ",max(sheet.X_shift), "min --> ", min(sheet.X_shift))
        H_to_large_or_small.append(bmrb_id)
# Out:
# 16677 : max -->  17.315 min -->  1.955
# 30069 : max -->  122.9 min -->  7.31
# 30208 : max -->  178.0 min -->  4.789
# 30774 : max -->  23.128 min -->  7.154

# %%
keys = list(chemical_shifts)

# %%
len(keys)
# Out:
# 5819

# %%
for bmrb_id in H_to_large_or_small:
    keys.remove(bmrb_id)

# %% [markdown]
# # N-Shifts

# %%
plt.figure(figsize=(15,10))
for sheet in chemical_shifts.values():
    plt.hist(sheet.Y_shift, 100, density=False, alpha=0.75, histtype="stepfilled", color="black")
plt.title("N-Shifts")
plt.show()

# %% [markdown]
# ## Filtering

# %%
N_to_large_or_small = []
for bmrb_id, sheet in chemical_shifts.items():
    if max(sheet.Y_shift) > 150 or min(sheet.Y_shift) < 80:
        print(bmrb_id, ":", "max --> ",max(sheet.Y_shift), "min --> ", min(sheet.Y_shift))
        N_to_large_or_small.append(bmrb_id)
# Out:
# 4114 : max -->  125.87 min -->  7.94
# 4188 : max -->  176.86 min -->  105.23
# 4224 : max -->  129.49 min -->  67.14
# 5304 : max -->  155.14 min -->  102.14
# 6493 : max -->  177.25 min -->  102.81
# 6776 : max -->  129.309 min -->  58.147
# 7184 : max -->  127.336 min -->  20.4
# 7291 : max -->  174.43 min -->  108.16
# 10012 : max -->  125.8 min -->  11.09
# 11012 : max -->  132.489 min -->  12.0
# 15877 : max -->  159.135 min -->  101.093
# 16207 : max -->  124.365 min -->  42.648
# 16239 : max -->  124.571 min -->  64.792
# 16250 : max -->  162.194 min -->  106.044
# 17016 : max -->  131.06 min -->  19.34
# 17305 : max -->  181.029 min -->  103.691
# 18132 : max -->  130.325 min -->  0.031
# 18571 : max -->  177.623 min -->  106.83
# 18953 : max -->  179.042 min -->  103.207
# 19143 : max -->  134.9 min -->  0.0
# 19718 : max -->  130.2 min -->  0.0
# 25176 : max -->  68.795 min -->  12.013
# 25442 : max -->  433.808 min -->  103.601
# 26593 : max -->  131.8 min -->  8.363
# 30069 : max -->  212.2 min -->  105.1
# 34081 : max -->  4.256 min -->  4.256
# 34487 : max -->  154.7 min -->  97.542
# 50938 : max -->  128.9 min -->  40.7

# %%
for bmrb_id in N_to_large_or_small:
    if bmrb_id not in H_to_large_or_small:
        print(bmrb_id)
        keys.remove(bmrb_id)
# Out:
# 4114
# 4188
# 4224
# 5304
# 6493
# 6776
# 7184
# 7291
# 10012
# 11012
# 15877
# 16207
# 16239
# 16250
# 17016
# 17305
# 18132
# 18571
# 18953
# 19143
# 19718
# 25176
# 25442
# 26593
# 34081
# 34487
# 50938

# %%
len(keys)
# Out:
# 5788

# %%
keys[:10]
# Out:
# [3322, 4023, 4052, 4053, 4089, 4090, 4129, 4141, 4147, 4153]

# %% [markdown]
# ---

# %%
with open("filtered_by_shifts.txt", "w") as outfile:
    outfile.writelines(",".join(map(str, keys)))
